# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import statsmodels.api as st
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
import math
from sklearn import preprocessing
import scipy.stats as stats
import pandas as pd
import urllib
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
hour=pd.read_csv('../Homework_2/hour.csv')
hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# 5            6  2011-01-01       1   0     1   5        0        6
# 6            7  2011-01-01       1   0     1   6        0        6
# 7            8  2011-01-01       1   0     1   7        0        6
# 8            9  2011-01-01       1   0     1   8        0        6
# 9           10  2011-01-01       1   0     1   9        0        6
# 10          11  2011-01-01       1   0     1  10        0        6
# 11          12  2011-01-01       1   0     1  11        0        6
# 12          13  2011-01-01       1   0     1  12        0        6
# ...

# %%
plt.hist(hour["cnt"])
plt.xlabel('cnt')
plt.ylabel('number')
plt.title('Histogram of cnt')
# Out:
# Text(0.5,1,'Histogram of cnt')

# %%
plt.hist(hour['temp'])
plt.xlabel('temp')
plt.ylabel('number')
plt.title('Histogram of temp')
# Out:
# Text(0.5,1,'Histogram of temp')

# %%
plt.hist(hour['atemp'])
plt.xlabel('atemp')
plt.ylabel('number')
plt.title('Histogram of atemp')
# Out:
# Text(0.5,1,'Histogram of atemp')

# %%
plt.hist(hour['windspeed'])
plt.xlabel('windspeed')
plt.ylabel('number')
plt.title('Histogram of windspeed')
# Out:
# Text(0.5,1,'Histogram of windspeed')

# %%
plt.hist(hour['hum'])
plt.xlabel('hum')
plt.ylabel('number')
plt.title('Histogram of hum')
# Out:
# Text(0.5,1,'Histogram of hum')

# %%
plt.hist(hour['hr'])
# Out:
# (array([2165., 1394., 1442., 2181., 1454., 1457., 2188., 1458., 1456.,
#         2184.]),
#  array([ 0. ,  2.3,  4.6,  6.9,  9.2, 11.5, 13.8, 16.1, 18.4, 20.7, 23. ]),
#  <a list of 10 Patch objects>)

# %%
sanggwan1 = hour[["temp","cnt"]]
sanggwan1.corr()
# Out:
#           temp       cnt
# temp  1.000000  0.404772
# cnt   0.404772  1.000000

# %%
sanggwan2 = hour[["hr","cnt"]]
sanggwan2.corr()
# Out:
#            hr       cnt
# hr   1.000000  0.394071
# cnt  0.394071  1.000000

# %%
sanggwan3 = hour[["hum","cnt"]]
sanggwan3.corr()
# Out:
#           hum       cnt
# hum  1.000000 -0.322911
# cnt -0.322911  1.000000

# %%
sanggwan4 = hour[["windspeed","cnt"]]
sanggwan4.corr()
# Out:
#            windspeed       cnt
# windspeed   1.000000  0.093234
# cnt         0.093234  1.000000

# %%
sanggwan5 = hour[["windspeed","hum","temp","cnt"]]
sanggwan5.corr()
# Out:
#            windspeed       hum      temp       cnt
# windspeed   1.000000 -0.290105 -0.023125  0.093234
# hum        -0.290105  1.000000 -0.069881 -0.322911
# temp       -0.023125 -0.069881  1.000000  0.404772
# cnt         0.093234 -0.322911  0.404772  1.000000

# %%
#cnt 로그변환
hour['logcnt'] = preprocessing.scale(np.log(hour['cnt']))
hour.logcnt
# Out:
# 0       -1.186663
# 1       -0.570087
# 2       -0.720241
# 3       -1.326384
# 4       -3.052351
# 5       -3.052351
# 6       -2.585929
# 7       -2.313089
# 8       -1.653085
# 9       -1.276517
# 10      -0.640984
# 11      -0.343673
# 12      -0.070834
# 13       0.004853
# 14       0.085699
# 15       0.110624
# 16      -0.002343
# 17      -0.222994
# 18      -0.659941
# 19      -0.622547
# 20      -0.640984
# 21      -0.679446
# 22      -0.810095
# 23      -0.587123
# 24      -1.145868
# 25      -1.145868
# 26      -1.573828
# 27      -1.846668
# 28      -2.313089
# 29      -2.585929
#            ...
# 17349    0.196644
# 17350    0.059815
# 17351   -0.174562
# 17352   -0.461569
# 17353   -0.640984
# 17354   -0.433527
# 17355   -0.679446
# 17356   -1.071024
# 17357   -1.438796
# 17358   -3.052351
# 17359   -2.313089
# 17360   -1.573828
# 17361   -0.570087
# 17362   -0.062870
# 17363    0.499317
# 17364    0.350021
# 17365    0.169175
# 17366    0.350021
# 17367    0.589171
# ...

# %%
dajung1=hour[["temp","hum","windspeed","logcnt"]]

# %%
result1 = sm.ols(formula = 'logcnt ~ temp + hum + windspeed', data = dajung1).fit()

result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 logcnt   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     1887.
# Date:                Thu, 28 Mar 2019   Prob (F-statistic):               0.00
# Time:                        13:56:26   Log-Likelihood:                -22209.
# No. Observations:               17379   AIC:                         4.443e+04
# Df Residuals:                   17375   BIC:                         4.446e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0221      0.034     -0.647      0.518      -0.089       0.045
# ...

# %%
Y_pred1 = result.predict(hour[["temp","hum","windspeed"]])
residual1 = hour["logcnt"].values-Y_pred1
residual1
# Out:
# 0       -0.360257
# 1        0.278735
# 2        0.128581
# 3       -0.593305
# 4       -2.319271
# 5       -2.344828
# 6       -1.737107
# 7       -1.332971
# 8       -0.920005
# 9       -0.679764
# 10      -0.230506
# 11       0.174020
# 12       0.270730
# 13       0.188455
# 14       0.273550
# 15       0.409968
# 16       0.412742
# 17       0.158372
# 18      -0.138750
# 19      -0.101357
# 20      -0.097378
# 21      -0.118811
# 22      -0.149107
# 23      -0.154651
# 24      -0.713397
# 25      -0.569322
# 26      -0.874513
# 27      -1.291063
# 28      -1.757485
# 29      -2.248615
#            ...
# 17349    0.362395
# 17350    0.385281
# 17351    0.067294
# 17352   -0.072689
# 17353   -0.198387
# 17354   -0.061676
# 17355   -0.198879
# 17356   -0.590456
# 17357   -0.849540
# 17358   -2.446067
# 17359   -1.513291
# 17360   -0.915300
# 17361    0.096941
# 17362    0.612686
# 17363    1.290616
# 17364    0.996106
# 17365    0.846562
# 17366    0.832420
# 17367    0.971382
# ...

# %%
#잔차분석
sns.distplot(residual1)
plt.title("Residual Analysis")
plt.xlim(-800, 800)
plt.show()
print("std of residual = ",residual1.std())
print("meanof residual = ",residual1.mean())
# Out:
# std of residual =  90.44910234334331
# meanof residual =  -189.46308763450142

# %%
#오리지날
dajung=hour[["temp","hum","windspeed","cnt"]]

# %%
result = sm.ols(formula = 'cnt ~ temp + hum + windspeed', data = dajung).fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     1945.
# Date:                Wed, 27 Mar 2019   Prob (F-statistic):               0.00
# Time:                        23:06:54   Log-Likelihood:            -1.1253e+05
# No. Observations:               17379   AIC:                         2.251e+05
# Df Residuals:                   17375   BIC:                         2.251e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    175.8100      6.187     28.416      0.000     163.683     187.937
# ...

# %%
my_formula = 'cnt ~ temp + hum + windspeed'
lm=ols(my_formula, data=dajung).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     1945.
# Date:                Wed, 27 Mar 2019   Prob (F-statistic):               0.00
# Time:                        22:12:19   Log-Likelihood:            -1.1253e+05
# No. Observations:               17379   AIC:                         2.251e+05
# Df Residuals:                   17375   BIC:                         2.251e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    175.8100      6.187     28.416      0.000     163.683     187.937
# ...

# %%
Y_pred = result.predict(hour[["temp","hum","windspeed"]])
residual = hour["cnt"].values-Y_pred
residual
# Out:
# 0        -25.311522
# 1          3.204515
# 2         -4.795485
# 3        -44.719429
# 4        -56.719429
# 5        -59.077686
# 6        -34.795485
# 7        -10.136890
# 8        -49.719429
# 9        -69.987531
# 10       -76.416937
# 11       -36.279956
# 12       -40.970625
# 13       -59.537423
# 14       -47.145257
# 15       -22.613479
# 16       -18.689535
# 17       -51.548058
# 18       -59.102500
# 19       -57.102500
# 20       -53.586463
# 21       -54.015169
# 22       -41.659574
# 23       -70.783005
# 24       -92.783005
# 25       -67.945282
# 26       -53.073650
# 27       -84.624677
# 28       -87.624677
# 29      -123.362791
#             ...
# 17349    -25.350082
# 17350    -30.257986
# 17351    -63.682403
# 17352    -66.171394
# 17353    -67.017121
# 17354    -65.742688
# 17355    -61.766432
# 17356    -76.766432
# 17357    -65.792809
# 17358    -74.221515
# 17359    -37.624316
# 17360    -54.903884
# 17361    -23.119553
# 17362     22.667409
# ...

# %%
#잔차분석
sns.distplot(residual)
plt.title("Residual Analysis")
plt.xlim(-800, 800)
plt.show()
print("std of residual = ",residual.std())
print("meanof residual = ",residual.mean())
# Out:
# std of residual =  156.94395807211833
# meanof residual =  3.5518223828893687e-13

# %%
hour1=pd.read_csv('../Homework_2/hour_1.csv')
hour1
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# 5            6  2011-01-01       1   0     1   5        0        6
# 6            7  2011-01-01       1   0     1   6        0        6
# 7            8  2011-01-01       1   0     1   7        0        6
# 8            9  2011-01-01       1   0     1   8        0        6
# 9           10  2011-01-01       1   0     1   9        0        6
# 10          11  2011-01-01       1   0     1  10        0        6
# 11          12  2011-01-01       1   0     1  11        0        6
# 12          13  2011-01-01       1   0     1  12        0        6
# ...

# %%
hour1['logcnt'] = preprocessing.scale(np.log(hour1['cnt']))
dajung2=hour1[["wc1","wc2","temp","hum","windspeed","logcnt"]]

# %%
result2 = sm.ols(formula = 'logcnt ~wc1+wc2 + temp + hum + windspeed', data = dajung2).fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 logcnt   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     1168.
# Date:                Sat, 30 Mar 2019   Prob (F-statistic):               0.00
# Time:                        16:36:06   Log-Likelihood:                -22141.
# No. Observations:               17379   AIC:                         4.429e+04
# Df Residuals:                   17373   BIC:                         4.434e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2171      0.054      4.037      0.000       0.112       0.322
# ...

# %%
anova=st.stats.anova_lm(result2)
anova
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                 df        sum_sq      mean_sq            F        PR(>F)
# wc1            1.0    267.805429   267.805429   357.736701  5.442687e-79
# wc2            1.0     30.709376    30.709376    41.021837  1.544019e-10
# temp           1.0   2462.597268  2462.597268  3289.557741  0.000000e+00
# hum            1.0   1596.772165  1596.772165  2132.981428  0.000000e+00
# windspeed      1.0     15.506592    15.506592    20.713833  5.369080e-06
# ...

# %%
Y_pred = result.predict(hour1[["wc1","wc2","temp","hum","windspeed"]])
residual2 = hour1["logcnt"].values-Y_pred
residual2
# Out:
# 0       -0.285826
# 1        0.352521
# 2        0.202367
# 3       -0.525751
# 4       -2.251717
# 5       -2.460178
# 6       -1.663321
# 7       -1.251807
# 8       -0.852451
# 9       -0.613069
# 10      -0.158887
# 11       0.252628
# 12       0.343250
# 13       0.069445
# 14       0.154163
# 15       0.297190
# 16       0.306196
# 17       0.050947
# 18      -0.096048
# 19      -0.058655
# 20      -0.198827
# 21      -0.221773
# 22      -0.243289
# 23      -0.255323
# 24      -0.814069
# 25      -0.663751
# 26      -0.960806
# 27      -1.387506
# 28      -1.853928
# 29      -2.217385
#            ...
# 17349    0.216809
# 17350    0.434283
# 17351    0.111579
# 17352   -0.027479
# 17353   -0.147837
# 17354   -0.014953
# 17355   -0.147828
# 17356   -0.539406
# 17357   -0.794159
# 17358   -2.392198
# 17359   -1.447460
# 17360   -0.853433
# 17361    0.158053
# 17362    0.673040
# 17363    1.357202
# 17364    0.870031
# 17365    0.726471
# 17366    0.703025
# 17367    0.836901
# ...

# %%
#잔차분석
sns.distplot(residual2)
plt.title("Residual Analysis")
plt.xlim(-5, 5)
plt.show()
print("std of residual = ",residual2.std())
print("meanof residual = ",residual2.mean())
# Out:
# std of residual =  0.8650982889596348
# meanof residual =  7.622681791578068e-16

# %%
#testing data
training=pd.read_csv('../Homework_2/training.csv')
training
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# 5            6  2011-01-01       1   0     1   5        0        6
# 6            7  2011-01-01       1   0     1   6        0        6
# 7            8  2011-01-01       1   0     1   7        0        6
# 8            9  2011-01-01       1   0     1   8        0        6
# 9           10  2011-01-01       1   0     1   9        0        6
# 10          11  2011-01-01       1   0     1  10        0        6
# 11          12  2011-01-01       1   0     1  11        0        6
# 12          13  2011-01-01       1   0     1  12        0        6
# ...

# %%
training['logcnt'] = preprocessing.scale(np.log(training['cnt']))
dajung3=training[["wc1","wc2","temp","hum","windspeed","logcnt"]]

# %%
result3 = sm.ols(formula = 'logcnt ~wc1+wc2 + temp + hum + windspeed', data = dajung3).fit()

result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 logcnt   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     1168.
# Date:                Thu, 28 Mar 2019   Prob (F-statistic):               0.00
# Time:                        02:01:50   Log-Likelihood:                -22141.
# No. Observations:               17379   AIC:                         4.429e+04
# Df Residuals:                   17373   BIC:                         4.434e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2171      0.054      4.037      0.000       0.112       0.322
# ...

# %%
hour_testing=pd.read_csv('../Homework_2/testing.csv')
hour_testing
# Out:
#       instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0           0  2012-08-07       3   1     8  13        0        2           1
# 1           1  2012-08-07       3   1     8  14        0        2           1
# 2           2  2012-08-07       3   1     8  15        0        2           1
# 3           3  2012-08-07       3   1     8  16        0        2           1
# 4           4  2012-08-07       3   1     8  17        0        2           1
# 5           5  2012-08-07       3   1     8  18        0        2           1
# 6           6  2012-08-07       3   1     8  19        0        2           1
# 7           7  2012-08-07       3   1     8  20        0        2           1
# 8           8  2012-08-07       3   1     8  21        0        2           1
# 9           9  2012-08-07       3   1     8  22        0        2           1
# 10         10  2012-08-07       3   1     8  23        0        2           1
# ...

# %%
hour_testing['logcnt'] = preprocessing.scale(np.log(hour_testing['cnt']))

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression

# %%
Y_pred3 = result3.predict(hour_testing[["wc1","wc2","temp","hum","windspeed"]])

plt.scatter(hour_testing['logcnt'],Y_pred3 )
plt.xlabel("log value of 'cnt'")
plt.ylabel("y hat")
plt.title("Compareness")
plt.show()

# %%
testing=list(hour_testing['logcnt'])
testing = [float (i) for i in testing]

Y_pred3 = result.predict(hour_testing[["wc1","wc2","temp","hum","windspeed"]])
Y_pred3=list(Y_pred3)
Y_pred3 = [float (i) for i in Y_pred3]

comp=[]

for i in range ( len (testing)):
    comp.append(testing[i]/Y_pred3[i])
comp
avg=np.mean(comp)
avg
# Out:
# 4.562928046618555
